 6.069408751, 6.056411489, 6.103698751, 6.118954661, 6.215927161, 6.08541611, 6.093995281, 6.082209468, 6.120353601, 6.120777201, 6.108258223, 6.01958386, 6.186372829, 6.10074575, 6.111826016, 6.028537371, 6.128614821, 6.093683739, 6.049903573, 6.090939767, 6.039046527, 6.184135675, 6.137752051, 6.122925837, 6.203001428, 6.050875241, 6.089922571, 6.056461428, 6.116541947, 6.099065603, 6.03550319, 6.014522954, 6.066399252, 6.125731709, 6.070761679, 6.195476879, 6.069813446, 6.118353754, 6.047994992, 6.023553432, 6.092854298, 6.070490872, 6.064869782, 5.979353344, 6.041301541, 6.018712421, 6.06539322, 6.029603146, 6.202831942]
len(yhat_in_rfscore)
# Out:
# 94

# %%
yhat_in_rfscore2 = [5.984129092, 6.169600943, 6.030669545, 6.007861003, 6.48249693, 6.008336511, 6.068701507, 5.952698767, 6.053329728, 6.059077472, 6.032607079, 6.312891762, 6.144108762, 6.033892319, 6.025302394, 6.049140227, 6.094491203, 6.024965378, 6.356248862, 6.045200208, 6.015280016, 6.258474629, 6.019226359, 6.366184872, 6.036081921, 6.271014133, 5.972850326, 6.099324233, 6.373973303, 6.034054048, 6.047456843, 6.031060682, 6.036604869, 6.307758624, 6.02485649, 5.971041863, 6.005630961, 6.259905433, 6.039846755, 6.062656521, 5.99546861, 6.006333021, 6.005474593, 6.020497073, 6.045377051, 6.044283325, 6.375169449, 6.07893902, 6.018554833, 6.033892319, 6.042582653, 6.029552454, 6.062656521, 6.042598712, 5.972850326, 6.015046809, 5.994345334, 6.029487995, 6.064386059, 6.032700357, 6.018386223, 6.452606432, 6.062656521, 6.276056059, 6.379682812, 6.033852912, 6.062722622, 6.372802844, 5.974542086, 6.041462965, 6.050332189, 5.988822949, 6.234876018, 6.038173365, 6.008336511, 6.135771713, 6.290051881, 5.988641032, 6.062994894, 6.049322149, 6.045626227, 5.979364459, 6.025302394, 5.997684246, 6.139016579, 6.238725923, 6.063869326, 5.972850326, 6.063530953, 6.042598712, 6.16456698, 6.342304257, 6.023314978, 6.03440163]

# %%
y = list(pd.read_csv('../data/test.csv')['G'])
yhat = [i for i in yhat_in if not np.isnan(i)]
y = [y[i] for i in range(len(yhat_in)) if not np.isnan(yhat_in[i])]

df = pd.DataFrame({'yhat': yhat, 'y': y})
# df = df[(np.abs(st.zscore(df)) < 3).all(axis=1)]
df = df.loc[df['y'] > 100]
plt.scatter(df['yhat'], df['y'])
plt.show()
stats.pearsonr(df['yhat'], df['y'])
# Out:
# PearsonRResult(statistic=0.3542207178541242, pvalue=0.010765911034040718)

# %%
y = list(pd.read_csv('../data/test.csv')['G'])
yhat = [i for i in yhat_in_rfscore2 if not np.isnan(i)]
y = [y[i] for i in range(len(yhat_in_rfscore2)) if not np.isnan(yhat_in_rfscore2[i])]

plt.scatter(yhat, y)
plt.show()
stats.pearsonr(yhat, y)
# Out:
# PearsonRResult(statistic=0.024702902659250077, pvalue=0.8131727024388612)
