# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pred_affinities = {1: 0.8104, 2: 0.5686, 3: 0.6408, 4: 0.6219, 5:0.7607, 6:0.9162, 7: 0.8781, 8:0.4270, 9: 0.7014, 10: 0.6515, 11: 0.6876, 12: 0.6571, 13: 0.6226, 14: 0.7715, 15: 0.7556, 16: 0.6957, 17: 0.5001, 18: 0.7504}
pred_binding = {1: 5.301, 2: 4.127, 3: 5.029, 4: 4.749, 5: 5.515, 6: 5.036, 7: 5.470, 8: 4.731, 9: 5.221, 10: 4.702, 11: 4.606, 12: 4.587, 13: 4.900, 14: 4.650, 15: 4.926, 16: 5.017, 17: 4.788, 18: 4.849}
yhat = [j for (i, j) in pred_binding.items()]
y = list(pd.read_csv('../data/test.csv')['G'])
y = y[:len(pred_affinities)]
plt.scatter(yhat, y)
plt.show()
np.corrcoef(yhat, y)
# Out:
# array([[ 1.        , -0.24227188],
#        [-0.24227188,  1.        ]])
