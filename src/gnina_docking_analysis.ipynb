# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %%
yhat1 = [0.5482, 0.7266, 0.6085, 0.4954, 0.4356, 0.6474, 0.5644, 0.5469, 0.3454, 0.7341, 0.5464, 0.4497, 0.5664, 0.6534, 0.4543, 0.3637, 0.5902, 0.6851, 0.5510, 0.5873, 0.4772, 0.6006, 0.7144, 0.5880, 0.5507, 0.4940, 0.4910, 0.5219, 0.5013, 0.4347, 0.5056, 0.4450]
yhat2 = [4.671, 4.650, 5.205, 4.658, 4.806, 5.220, 4.872, 5.611, 5.026, 5.376, 4.774, 4.639, 4.753, 4.548, 4.717, 5.211, 4.902, 5.139, 4.974, 4.697, 5.454, 5.048, 4.946, 5.449, 5.081, 5.097, 5.052, 4.728, 4.837, 5.038, 5.292, 5.115]

# %%
y = list(pd.read_csv('../data/test.csv')['G'])
y = y[:len(yhat1)]
print(y)
plt.scatter(yhat1, y)
plt.show()
print(st.pearsonr(yhat1, y))

plt.scatter(yhat2, y)
plt.show()
print(st.pearsonr(yhat2, y))
# Out:
# [165, 16, 1330, 1301, 17, 998, 205, 6, 4, 1401, 1494, 1300, 281, 9, 17, 726, 726, 1, 4921, 0, 684, 71, 299, 1276, 671, 0, 767, 1021, 0, 0, 2895, 262]
# PearsonRResult(statistic=0.02574627358978726, pvalue=0.8887616425156222)
# PearsonRResult(statistic=0.16370797265738415, pvalue=0.37063271269162595)
